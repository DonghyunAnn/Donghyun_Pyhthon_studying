# %% [markdown]
# # Interface란?
# * 인터페이스란 두가지의 객체를 이어주는 어떤 것을 말함
# * 서로간의 데이터가 잘 교환되도록하는 일종의 약속
#
# # API
# * 응용프로그램 프로그래밍 인터페이스
# * Application Programming Inteface
# * API를 만든다: 사용자가 필요한기능을 만들고 서버에 옮긴 뒤에 특정한 규약에 따라 사용할 수 있도록 하는 것
# * API를 사용한다: 누군가가 만든 기능을 특정한 규약에 따라 사용하는것
#
# ## Openweathermap API를 사용할 예정, 이런것을 openAPI라고 함
# * 누가 API를 사용하고있는지 남기는 방명록이 APIkey라고 함, 자신의 신원을 밝히고 쓰겠다고 말하는 것임
#
# ## Current Weather Data doc
# https://openweathermap.org/current

# %%
#파라미터를 각각 입력해줘야 함
#요청을 보내기 위해 requests를 해줌
city="Seoul"
apikey= "93d88dab98513859f271bbd01e473df1"
lang="kr"
api=f"http://api.openweathermap.org/data/2.5/\
weather?q={city}&appid={apikey}&lang={lang}&units=metric"
#lang은 API를 가져올 때 한국어로 가져오기 위해
#units=metric은 화씨를 섭씨로 바꾸기 위해

# %%
#API로 요청을 보내서 날씨 데이터 받아오기
import requests

results=requests.get(api)
print(result.text)
print(type(result.text))
# Out:
# {"coord":{"lon":126.9778,"lat":37.5683},"weather":[{"id":721,"main":"Haze","description":"haze","icon":"50d"}],"base":"stations","main":{"temp":288.81,"feels_like":285.43,"temp_min":288.15,"temp_max":289.15,"pressure":1026,"humidity":29},"visibility":5000,"wind":{"speed":1.54,"deg":360},"clouds":{"all":100},"dt":1615437501,"sys":{"type":1,"id":8105,"country":"KR","sunrise":1615412982,"sunset":1615455291},"timezone":32400,"id":1835848,"name":"Seoul","cod":200}
# <class 'str'>

# %% [markdown]
# * json
#   * JavaScriptObjectNotation의 줄임말
#   * 자바스크립트의 객체의 문법을 따르는 문자기반의 데이터 포맷
#   * 데이터를 주고받을 대 사용하는 포맷중 하나

# %%
# 타입이 str이고 이를 더 쉽게 가져오기 위해서 split 말고 json을 사용하고자 함
import json

data = json.loads(results.text)
print(data)
# Out:
# {'coord': {'lon': 126.9778, 'lat': 37.5683}, 'weather': [{'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50d'}], 'base': 'stations', 'main': {'temp': 288.81, 'feels_like': 285.43, 'temp_min': 288.15, 'temp_max': 289.15, 'pressure': 1026, 'humidity': 29}, 'visibility': 5000, 'wind': {'speed': 1.54, 'deg': 360}, 'clouds': {'all': 100}, 'dt': 1615437501, 'sys': {'type': 1, 'id': 8105, 'country': 'KR', 'sunrise': 1615412982, 'sunset': 1615455291}, 'timezone': 32400, 'id': 1835848, 'name': 'Seoul', 'cod': 200}

# %%
print(data["name"],"의 날씨입니다.")
print("날씨는",data['weather'][0]["description"],"입니다.")
print("현재 온도는 ",data["main"]["temp"],"입니다.")
print("하지만 체감 온도는 ",data["main"]["feels_like"],"입니다.")
print("최저 기온은 ",data["main"]["temp_min"],"입니다.")
print("최고 기온은 ",data["main"]["temp_min"],"입니다.")
print("습도는 ",data["main"]["humidity"],"입니다.")
print("기압은 ",data["main"]["pressure"],"입니다.")
print("풍향은 ",data["wind"]["deg"],"입니다.")
print("풍속은 ",data["wind"]["speed"],"입니다.")
# Out:
# Seoul 의 날씨입니다.
# 날씨는 haze 입니다.
# 현재 온도는  288.81 입니다.
# 하지만 체감 온도는  285.43 입니다.
# 최저 기온은  288.15 입니다.
# 최고 기온은  288.15 입니다.
# 습도는  29 입니다.
# 기압은  1026 입니다.
# 풍향은  360 입니다.
# 풍속은  1.54 입니다.
